# %% [markdown]
# # 📊 Notebook 01 – Exploratory Data Analysis (EDA)
# **Project:** Customer Churn Prediction
# **Dataset:** Telco Customer Churn (Kaggle)
#
# ---
# This notebook explores the raw dataset to understand:
# - Distribution of the target variable (Churn)
# - Feature distributions and correlations
# - Key patterns related to churn behaviour

# %%
import sys
sys.path.insert(0, '..')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

sns.set_theme(style='darkgrid', palette='muted')
pd.set_option('display.max_columns', None)
print('✅ Libraries loaded')

# %% [markdown]
# ## 1. Load Data

# %%
from src.data.load_data import load_raw_data, get_data_summary

df = load_raw_data()
get_data_summary(df)

# %%
df.head()

# %%
df.dtypes

# %% [markdown]
# ## 2. Target Distribution

# %%
from src.visualization.plots import plot_churn_distribution
plot_churn_distribution(df)

churn_rate = (df['Churn'] == 'Yes').mean()
print(f'\n📊 Overall Churn Rate: {churn_rate:.2%}')
print('⚠️  Dataset is imbalanced – churn minority class ~26%')

# %% [markdown]
# ## 3. Numeric Feature Distributions

# %%
from src.visualization.plots import plot_numeric_distributions
plot_numeric_distributions(df)

# %%
# Descriptive stats for numeric features
df[['tenure', 'MonthlyCharges', 'TotalCharges']].describe()

# %% [markdown]
# ## 4. Categorical Feature Churn Rates

# %%
from src.visualization.plots import plot_categorical_churn_rates
plot_categorical_churn_rates(df)

# %% [markdown]
# ## 5. Correlation Heatmap

# %%
from src.visualization.plots import plot_correlation_heatmap

# Fix TotalCharges for heatmap
df_num = df.copy()
df_num['TotalCharges'] = pd.to_numeric(df_num['TotalCharges'], errors='coerce')
plot_correlation_heatmap(df_num)

# %% [markdown]
# ## 6. Key Insights
#
# | Insight | Finding |
# |---|---|
# | Churn rate | ~26% of customers churned |
# | Tenure | Customers with shorter tenure churn more |
# | Contract type | Month-to-month contracts have highest churn |
# | Monthly charges | Higher charges → higher churn probability |
# | Payment method | Electronic check users churn most |
#
# ➡️ Proceed to **Notebook 02** for preprocessing.
